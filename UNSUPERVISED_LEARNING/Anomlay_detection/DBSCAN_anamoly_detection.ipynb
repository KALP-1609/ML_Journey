# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons,make_circles
import pandas as pd
import matplotlib.pyplot as plt

# %%
X,y = make_circles(n_samples=750,factor=0.3,noise=.1)

# %%
plt.figure(figsize=(10,8))
plt.scatter(X[:,0],X[:,1],c=y)

# %%
db = DBSCAN(eps=0.1)
db.fit_predict(X)
pred = db.labels_

# %%
plt.figure(figsize=(10,8))
plt.scatter(X[:,0],X[:,1],c=pred,cmap='Blues')

# %%
# Out:
# array([ 0,  1,  0,  0,  2,  0, -1,  0,  3,  3,  4,  5,  0,  6,  0,  6,  0,
#         0,  0,  0,  4,  0,  0,  0,  0, -1,  0,  0, -1,  7,  0,  0,  0,  0,
#         8, -1,  0,  0,  0,  0, -1,  1,  0, -1,  6,  0,  9,  6,  3,  0,  1,
#         4,  0,  0,  0, 10,  8,  0,  1, 11, 10,  0,  0, 12,  0, 13,  0,  1,
#         0, 14,  0,  4, 13, 11,  0,  0,  0,  6,  0,  0,  0, 12, 14,  0,  0,
#         0, 13,  0,  5, 12,  0,  4, 14,  5,  0,  0,  0,  0,  7,  9,  0,  0,
#         0,  3,  1,  0,  5,  0,  6,  1,  0,  0,  0, 11,  0,  1, 11, 10,  0,
#         5,  1,  9,  0,  0, -1, 12,  0,  0,  6, 13,  0,  0,  0, 11, -1, 12,
#         0,  8, 14,  0,  0,  0,  0,  9,  3,  0,  0,  6,  0,  0,  0,  3,  0,
#         0,  0,  1, 11,  0,  3,  0,  0,  0,  0,  8,  0, 11,  4, -1,  1,  0,
#         0,  0,  0, 12,  1, 12,  0, -1,  0, 11,  0,  0, -1, 11,  8,  0,  0,
#         0,  0,  0,  7,  0,  0,  0,  0,  2,  9,  8, 13,  0, 12,  9,  1,  0,
#        13,  0,  0, -1,  5, 11,  0,  0,  5,  3,  0,  0,  3,  0,  0, 14,  0,
#         0,  6,  0,  0,  0, 12,  0,  0,  0,  0,  0, 14,  0,  0,  9,  0,  0,
#         0, 14,  0, 12,  8,  0,  0,  3,  0, 12, -1, 10,  8,  0,  1,  5,  0,
#         3,  0,  0,  0,  0,  0, 12,  1,  3,  0,  3, -1,  0,  3,  5,  0,  6,
#         0,  0,  0, 13,  0, 12,  5,  3,  0, -1, 10,  0,  0,  0,  0,  0,  4,
#         9,  1,  1,  0,  0, 10,  0, -1,  0, 12,  0,  4,  6, 12,  0,  5,  0,
#         9,  0,  9, 14,  0,  1,  0,  5,  0,  0,  0,  0, -1,  9, 10,  8,  0,
#        13,  0,  3,  0, -1,  0, 13,  6,  9,  3,  1,  0, 14,  0, -1,  9,  5,
#        11,  0,  6,  0,  4,  0, 14,  0,  5,  6,  0, 12,  0, 12,  2,  4,  0,
#        -1, 14, 13,  1,  6, -1,  0,  0,  0,  6,  0, 12,  1,  5, 13, 12,  3,
#         5,  7,  3,  0,  8, 10,  0, 11,  0, 14,  2,  6,  0,  0, 11,  1,  4,
#         0, 12,  1,  8,  3,  0,  0,  6,  0,  0,  0,  4, 14,  9,  0,  0,  1,
#         7, -1, 13,  0,  0,  0,  8,  0,  5,  0,  0,  0, -1, 12,  5,  0,  3,
#         0,  8,  0, 14,  9,  5, 12,  4,  0,  0,  0,  0,  3,  0,  0,  3, 12,
#         0,  0,  0, -1,  0, 13,  0,  0, 11,  0,  4,  0,  0,  3, 11,  8,  0,
#         0,  1,  6,  0,  3,  0,  0,  1,  9,  8,  1,  0, 13, 11,  4,  3, 13,
#         0,  9,  0,  0,  0,  0,  0,  6,  0,  1,  2,  0,  0,  3,  5,  0, 12,
#         1,  0,  7,  5,  5,  1, 13,  0,  6,  0,  3,  9, 12,  0,  9, 11, 10,
#         0,  1, 13,  0,  0,  0,  0,  0,  0, 14,  6,  0, -1, 11,  0,  0, -1,
#         0, -1,  0,  4, 14,  0,  0,  0,  0,  0,  0, 11, 12,  6,  9,  0,  5,
#         0,  0,  0, 12, 12,  0,  4,  4,  0,  0,  0,  0,  4,  0,  8,  0,  0,
#         0,  5,  3,  9,  0,  0,  8,  2,  0,  3,  4, 11,  0,  0,  0,  1,  0,
#        11,  6,  4,  6,  5, 11,  0,  0, 13, 12,  0, 10,  0,  0,  0,  0, 11,
#         0,  0, -1,  0,  0,  0,  1,  0, -1,  0,  0,  0,  5,  0,  0,  0,  3,
#        11,  0,  1,  0,  5,  7,  2,  0, 11,  0,  0, 13,  0,  1,  8, 14,  0,
#         6, -1, 10,  1,  0, -1,  0,  0, 14,  0,  0,  0,  0, 12,  0,  4,  9,
#         0, 11,  0,  0,  0,  0,  0,  0,  5, 11,  0,  0,  0,  0,  5,  0,  0,
#        13,  1,  6,  9,  0,  9,  4,  3,  6,  0,  9, -1,  9,  0,  0,  0,  0,
#         0,  4,  8,  0, 12, 12,  9, 12,  0,  0, 12,  5,  8,  3,  0,  5, 14,
#         8,  0,  0,  0, 12,  9,  0,  0,  0,  0, 13,  0,  1, -1,  0,  0,  0,
#         0,  0,  5,  0, 10,  4,  0,  0,  0,  0, -1,  0,  5,  0,  0,  0,  4,
#         0,  1,  0,  0,  0,  0,  0,  0, -1,  3,  0,  8,  0, 13,  0,  0, -1,
#         0,  0])
